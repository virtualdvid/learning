# %%
import random, shutil, os, time
import numpy as np
import pandas as pd
from PIL import Image
from google_scraper import scrape

# %%
# size = 224, 224
images_per_class = 850
class_list = ['Nutria',
    'Virginia opossum',
    'Elk',
    'Columbian black-tailed deer',
    'Cougar',
    'Canada lynx',
    'Bobcat',
    'Deer',
    'Black bear',
    'Coyote',
    'Gray wolf',
    'Gray fox',
    'Red fox',
    'Raccoon',
    'Ringtail',
    'Mountain beaver',
    'Seals',
    'Sea lions',
    'Bald eagle',
    'Raven',
    ]

# %%
path = 'images/'

try:
    scrape(class_list, int(images_per_class), 'oregon_wildlife')
except Exception as e:
    print('Error. Skipping! {}'.format(e))
    
    ##Resize image
#     picture = os.listdir(path + folder)

#     for pic in picture:
#         img_name = str(int(time.time()))
#         try:
#             im = Image.open('{}{}/{}'.format(path, folder, pic)).convert('RGB')
#             im.thumbnail(im.size, Image.ANTIALIAS)
#             im.save('{}{}/{}.jpg'.format(path, folder, img_name), "JPEG", optimize=True)
#         except Exception as e:
# #             os.remove('{}{}/{}'.format(path, folder, pic))
#             print('Error. Skipping! {} image: {}'.format(e, pic))
#             continue
# Out:
# ===============================================
#
# [%] Nutria started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Nutria.
#
# ===============================================
#
# [%] Virginia opossum started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Virginia opossum.
#
# ===============================================
#
# [%] Elk started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Elk.
#
# ===============================================
#
# [%] Columbian black-tailed deer started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Columbian black-tailed deer.
#
# ===============================================
#
# [%] Cougar started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: https://news.nationalgeographic.com/content/dam/news/2018/05/21/cougar-attack/01-cougar-attack-NationalGeographic_1300877.jpg
# [%] Downloading Image #1 from https://news.nationalgeographic.com/content/dam/news/2018/05/21/cougar-attack/01-cougar-attack-NationalGeographic_1300877.jpg
# [%] Downloaded File
# [%] Loaded to json
#
# [%] Downloaded 1 images for label Cougar.
#
# ===============================================
#
# [%] Canada lynx started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Canada lynx.
#
# ===============================================
#
# [%] Bobcat started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: https://upload.wikimedia.org/wikipedia/commons/d/dc/Bobcat2.jpg
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/d/dc/Bobcat2.jpg
# [%] Downloaded File
# [%] Loaded to json
#
# [%] Downloaded 1 images for label Bobcat.
#
# ===============================================
#
# [%] Deer started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Deer.
#
# ===============================================
#
# [%] Black bear started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/01_Schwarzb%C3%A4r.jpg/220px-01_Schwarzb%C3%A4r.jpg
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/01_Schwarzb%C3%A4r.jpg/220px-01_Schwarzb%C3%A4r.jpg
# [%] Downloaded File
# [%] Loaded to json
#
# [%] Downloaded 1 images for label Black bear.
#
# ===============================================
#
# [%] Coyote started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Coyote.
#
# ===============================================
#
# [%] Gray wolf started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: https://www.nwf.org/-/media/NEW-WEBSITE/Shared-Folder/Wildlife/Mammals/mammal_gray-wolf_600x300.ashx
# [%] Downloading Image #1 from https://www.nwf.org/-/media/NEW-WEBSITE/Shared-Folder/Wildlife/Mammals/mammal_gray-wolf_600x300.ashx
# [%] Downloaded File
# [%] Loaded to json
#
# [%] Downloaded 1 images for label Gray wolf.
#
# ===============================================
#
# [%] Gray fox started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Gray fox.
#
# ===============================================
#
# [%] Red fox started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: https://www.nationalgeographic.com/content/dam/animals/thumbs/rights-exempt/mammals/r/red-fox_thumb.JPG
# [%] Downloading Image #1 from https://www.nationalgeographic.com/content/dam/animals/thumbs/rights-exempt/mammals/r/red-fox_thumb.JPG
# [%] Downloaded File
# [%] Loaded to json
#
# [%] Downloaded 1 images for label Red fox.
#
# ===============================================
#
# [%] Raccoon started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Raccoon.
#
# ===============================================
#
# [%] Ringtail started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Ringtail.
#
# ===============================================
#
# [%] Mountain beaver started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Mountain beaver.
#
# ===============================================
#
# [%] Seals started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: http://www.mysticaquarium.org/wp-content/uploads/2016/06/Harbor-Seal-Trey-0353.jpg
# [%] Downloading Image #1 from http://www.mysticaquarium.org/wp-content/uploads/2016/06/Harbor-Seal-Trey-0353.jpg
# [!] Issue Downloading: http://www.mysticaquarium.org/wp-content/uploads/2016/06/Harbor-Seal-Trey-0353.jpg
# [!] Error: HTTP Error 403: Forbidden
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Seals.
#
# ===============================================
#
# [%] Sea lions started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Sea lions.
#
# ===============================================
#
# [%] Bald eagle started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: Google
# [%] Downloading Image #1 from Google
# [!] Issue Downloading: Google
# [!] Error: unknown url type: 'Google'
# [%] Loaded to json
#
# [%] Downloaded 0 images for label Bald eagle.
#
# ===============================================
#
# [%] Raven started.
#
# ===============================================
#
#
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\S372277\.wdm\chromedriver\2.46\win32/chromedriver.exe
#
# ===============================================
#
# [%] Successfully launched Chrome Browser
# [%] Successfully opened link.
# [%] Scrolling down.
# [%] Reached end of Page.
# [%] Closed Browser.
# [%] Indexed 400 Images.
#
# ===============================================
#
# [%] Getting Image Information.
#
#
# [%] Getting info on: https://upload.wikimedia.org/wikipedia/commons/a/a7/Head_of_Raven.jpg
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/a/a7/Head_of_Raven.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://d1ia71hq4oe7pn.cloudfront.net/og/75335511-1200px.jpg
# [%] Downloading Image #2 from https://d1ia71hq4oe7pn.cloudfront.net/og/75335511-1200px.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://cdn.britannica.com/s:300x300/15/130115-004-36F496B8.jpg
# [%] Downloading Image #3 from https://cdn.britannica.com/s:300x300/15/130115-004-36F496B8.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://d1ia71hq4oe7pn.cloudfront.net/photo/70579921-480px.jpg
# [%] Downloading Image #4 from https://d1ia71hq4oe7pn.cloudfront.net/photo/70579921-480px.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://www.sciencemag.org/sites/default/files/styles/inline__450w__no_aspect/public/Common_raven_by_David_Hofmann%20%281%29.jpg?itok=_zxdLBGr
# [%] Downloading Image #5 from https://www.sciencemag.org/sites/default/files/styles/inline__450w__no_aspect/public/Common_raven_by_David_Hofmann%20%281%29.jpg?itok=_zxdLBGr
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: http://sciencenordic.com/sites/default/files/imagecache/620x/ravn-corvus_corax.jpg
# [%] Downloading Image #6 from http://sciencenordic.com/sites/default/files/imagecache/620x/ravn-corvus_corax.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https
jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://static1.squarespace.com/static/54617a87e4b0ead3d2d3f469/t/5583217be4b041556cba4946/1434657148693/
# [%] Downloading Image #58 from https://static1.squarespace.com/static/54617a87e4b0ead3d2d3f469/t/5583217be4b041556cba4946/1434657148693/
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://cdn.audubon.org/cdn/farfuture/yNcHlMA-_WljDDmuaKl5WOmpFTwVMGF_9ufZP7IvvGc/mtime:1499975670/sites/default/files/styles/hero_image/public/junolillen.jpg?itok=PGRYReVt
# [%] Downloading Image #59 from https://cdn.audubon.org/cdn/farfuture/yNcHlMA-_WljDDmuaKl5WOmpFTwVMGF_9ufZP7IvvGc/mtime:1499975670/sites/default/files/styles/hero_image/public/junolillen.jpg?itok=PGRYReVt
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://image.shutterstock.com/image-illustration/painted-bird-raven-front-on-260nw-1086321278.jpg
# [%] Downloading Image #60 from https://image.shutterstock.com/image-illustration/painted-bird-raven-front-on-260nw-1086321278.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://ichef.bbci.co.uk/images/ic/640x360/p06y4rvj.jpg
# [%] Downloading Image #61 from https://ichef.bbci.co.uk/images/ic/640x360/p06y4rvj.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://www.beautyofbirds.com/images/birds/ravens/ThickbilledRaven3.jpg
# [%] Downloading Image #62 from https://www.beautyofbirds.com/images/birds/ravens/ThickbilledRaven3.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://www.thoughtco.com/thmb/DGMfA9AZNdxdaNbgjKnJIrRqsmw=/768x0/filters:no_upscale():max_bytes(150000):strip_icc()/crow-on-a-branch-908388780-5aa1e7653de423003606e26e.jpg
# [%] Downloading Image #63 from https://www.thoughtco.com/thmb/DGMfA9AZNdxdaNbgjKnJIrRqsmw=/768x0/filters:no_upscale():max_bytes(150000):strip_icc()/crow-on-a-branch-908388780-5aa1e7653de423003606e26e.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://media.treehugger.com/assets/images/2017/06/raven.jpg.860x0_q70_crop-scale.jpg
# [%] Downloading Image #64 from https://media.treehugger.com/assets/images/2017/06/raven.jpg.860x0_q70_crop-scale.jpg
# [%] Downloaded File
# [%] Loaded to json
#
#
# [%] Getting info on: https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1659588290988611
# [%] Downloading Image #65 from https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1659588290988611
# [%] Downloaded File
# [%] Loaded to json
#
# [%] Downloaded 65 images for label Raven.

# %% [markdown]
# ## Backup

# %%
df = pd.read_csv('pokemon.csv', header='infer', delimiter=',')
pokemon_list = df['name'].tolist()
pokemon_list

# %% [markdown]
# ### Clean broken images

# %%
for filename in os.listdir('images'):
    for picture in os.listdir('images/' + filename):
        if picture.endswith('.jpg'):
            try:
                img=Image.open('images/' + filename + '/' + picture)
                img.verify()
            except:
                os.remove('Pokemons/' + filename + '/' + picture)

# %% [markdown]
# ### Rename folders if it's required

# %%
for filename in os.listdir('data/raw'):
    if filename.startswith("pokemon_"):
        os.rename('data/raw/'+filename, 'data/raw/'+filename[8:])

# %%
class_list = [# 'camellias',
#     'western red cedar tree',
#     'redwood cedar tree',
    'rhododendrons',
    'shrub',
    'rose hips',
#     'cherry trees',
#     'Daphne flower'
    ]
